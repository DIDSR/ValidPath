# %% [markdown]
# # Patch Extraction
#
# Click to open in:  \[[GitHub](https://github.com/DIDSR/wsi_processing_toolbox/03_patch_extraction.ipynb)\]
#
# Developer: Seyed.kahaki@fda.hhs.gov

# %% [markdown]
# ## Patch Extraction Demo
# This demonstration guides you through the process of using WSIToolbox to extract patches within annotations. This feature enabled using the patch_extraction method.

# %% [markdown]
# ## Environment Configuration
# Please follow the instruction provided in the Installation section to install related dependencies. If this isn't your first time running this code and you have all these packages installed, you can skip to the next step. If you choose to run it regardless, you might encounter an error message; however, this won't negatively impact your session. On Jupyter Notebook, this cell is responsible for installing required packages for patch extraction module. If you haven’t installed the packages based on the instruction provided for the WSI Reader module, please install these packages as well

# %%
# to check the python version
from platform import python_version
print(python_version())
#pip install mpmath==1.2.1
#pip install lxml==4.9.1
#!apt-get -y install libopenjp2-7-dev libopenjp2-tools openslide-tools | tail --line 1
#pip install cv2== 4.5.3
#pip install openslide-python==1.1.2
#pip install Shapely==1.7.1
#pip install tifffile==2022.10.10
#pip install random
#pip install glob
print("Installation is done.")
# Out:
# 3.8.8
# Installation is done.

# %% [markdown]
# ## Cleaning up residual files from prior sessions
#
# The following cell will delete the output directory (for example: C:/Users/data), assuming it exists due to an earlier run of this notebook. If this is your initial run, you can disregard this step.

# %%
#![ -d 'C:/Users/data' ] && ( echo "deleting tmp directory"; rm -rf 'C:/Users/data' )

# %% [markdown]
# ## Loading Required Packages
#
# In this step, we will import several Python modules that are needed for our analysis.

# %%
import os
from WSI.readwsi import WSIReader
from WSI.patch import WSIpatch_extractor
from WSI.patch import PatchExtractor
import matplotlib.pyplot as plt

# %% [markdown]
# ## Patch extraction from annotated area
# In this demonstration, we show you how to extract image patches from the annotated region of the WSI. We do this by using WSIToolbox's PatchExtractor class. This step should be run after extracting the annotated area of the WSI. If you haven't extract the annotations, in order to extract the image patches. please follow the steps in this Notebook github.com/DIDSR/wsi_processing_toolbox/02_annotation_extraction.ipynb. After extracting the image patches, you can call the gen_patch method from the annotation.patch_extractor class to extract image patches. Please make sure that you imported the PatchExtractor class using "from annotation.patch_extractor import PatchExtractor". Please run the following code to generate image patches from the annotated area.

# %%
INPUTDIR = 'C:/DATA/0_Washu-Aperio/input_output/'
PatchSize = (255,255)
Number_of_Patches = 10
OUTPUTDIR = 'C:/DATA/0_Washu-Aperio/out_dir/'
intensity_check = False
intensity_threshold = 250

PatchExtractor.gen_patch(INPUTDIR,PatchSize,Number_of_Patches,intensity_check,intensity_threshold,OUTPUTDIR)
# Out:
# C:/DATA/0_Washu-Aperio/input_output/
# <<<<<<<<<
# >>>>>>>>>
# ['C:/DATA/0_Washu-Aperio/input_output\\aperio-002-0', 'C:/DATA/0_Washu-Aperio/input_output\\aperio-117-0']
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-002-0/0_aperio-002-0_x_46_y_105_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-002-0/1_aperio-002-0_x_622_y_810_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-002-0
a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/7_aperio-117-0_x_1_y_326_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/8_aperio-117-0_x_41_y_348_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/9_aperio-117-0_x_32_y_31_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/0_aperio-117-0_x_88_y_96_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/1_aperio-117-0_x_415_y_59_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/2_aperio-117-0_x_193_y_360_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/3_aperio-117-0_x_176_y_580_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/4_aperio-117-0_x_407_y_549_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/5_aperio-117-0_x_96_y_380_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/6_aperio-117-0_x_198_y_32_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/7_aperio-117-0_x_339_y_346_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/8_aperio-117-0_x_327_y_508_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/9_aperio-117-0_x_308_y_48_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/0_aperio-117-0_x_370_y_653_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/1_aperio-117-0_x_525_y_644_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/2_aperio-117-0_x_416_y_1183_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/3_aperio-117-0_x_698_y_554_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/4_aperio-117-0_x_290_y_143_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/5_aperio-117-0_x_616_y_674_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/6_aperio-117-0_x_486_y_982_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/7_aperio-117-0_x_301_y_808_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/8_aperio-117-0_x_236_y_479_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/9_aperio-117-0_x_486_y_930_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/0_aperio-117-0_x_-41_y_156_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/0_aperio-117-0_x_62_y_122_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/1_aperio-117-0_x_85_y_173_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/2_aperio-117-0_x_-91_y_192_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/2_aperio-117-0_x_20_y_212_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/3_aperio-117-0_x_19_y_190_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/4_aperio-117-0_x_-45_y_90_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/4_aperio-117-0_x_102_y_-12_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/4_aperio-117-0_x_58_y_215_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/5_aperio-117-0_x_34_y_27_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/6_aperio-117-0_x_26_y_211_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/7_aperio-117-0_x_54_y_120_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/8_aperio-117-0_x_137_y_50_a_100.00.png
# C:/DATA/0_Washu-Aperio/out_dir/data/png_files/
# Creating C:/DATA/0_Washu-Aperio/out_dir/data/png_files/aperio-117-0/9_aperio-117-0_x_44_y_94_a_100.00.png

# %% [markdown]
# ## Patch Extraction from the entire WSI
# In this section, we load a WSI and create the WSI object. This is enabled using the wsi_reader method in the ReadWsi package. For this, we will set up a directory which contains our WSI files, we will create a list in Python and append WSI names in this list and load the WSI using the wsi_reader using an index.

# %% [markdown]
# ### Read WSI

# %%
while True:
    
    # loading input directory
    dir_file = input(r"Please enter the file directory, for example: C:\DATA\0_Washu-Aperio\: ")
    # Getting the wsi file name
    file_name = input("Please enter the file name, for example: aperio-002-0.svs:")
    print("\n")
    path = dir_file + "\\" + file_name
    
    #Checking folder availability 
    if os.path.exists(path):
        # reading wsi file 
        wsi_obj =WSIReader.wsi_reader(path)
        break
    else:
        print("File path error!" )

print(" Done...")
# Out:
# Please enter the file directory, for example: C:\DATA\0_Washu-Aperio\: C:\DATA\0_Washu-Aperio\
# Please enter the file name, for example: aperio-002-0.svs:aperio-002-0.svs
#
#
#  Done...

# %% [markdown]
# After reading the WSI using the wsi_reader, we have an object which has the loaded WSI. To validate if the object is loaded correctly, we print the object and also print the available pyramid levels of the WSI using the “.level_dimensions” method.

# %%
#wsi_obj =ReadWsi.wsi_reader('C:/DATA/0_Washu-Aperio/aperio-002-0.svs')
print(wsi_obj)
print(wsi_obj.level_dimensions)
# Out:
# OpenSlide('C:\\DATA\\0_Washu-Aperio\\\\aperio-002-0.svs')
# ((123503, 38380), (30875, 9595), (7718, 2398), (3859, 1199))

# %% [markdown]
# ### Thumbnail Visualization
#
# To see a thumbnail of the WSI, we use the get_thumbnail method of wsi_reader. We load the thumbnail as follows:

# %%
###################################  WSI thumbnail code to show the WSI in small size

#Getting the thumbnail size from the user
size_ = [int (input("Please enter x-size in pixels, for example: 600 ... ")),int (input("Please enter y-size in pixels, for example: 300 ..."))]
#for example: size_ = (600,300)

#Getting the thumbnail 
tile= wsi_obj.get_thumbnail(size=size_)

plt.imshow(tile)
plt.title("WSI thumbnail")
# Out:
# Please enter x-size in pixels, for example: 600 ... 600
# Please enter y-size in pixels, for example: 300 ...300
# Text(0.5, 1.0, 'WSI thumbnail')

# %% [markdown]
# ### Extract Image Patches from the WSI

# %%
while True:
    intensity_threshold = 250
    std_threshold = 15
    #Setting the patch size
    patchsize = int(input(r"Please enter the patch size, for example 255: "))
    
    #Setting the output directory
    output_directory = input(r"Please enter the output directory, for example C:/DATA/0_Washu-Aperio/out_dir/:")
    
    
    # Setting the random state. 
    #       1: Extract patches randomly from the whole slide image. In this case, please make sure that you entered
    #          the maximum number of patches to be extracted
    #       0: Extract patches starting from the beginning of the whole slide image
    
    random = int(input(r"Please enter set the random variable (1 = randomize ,  0 = non-randomized)"))
    if random==1 :
        random= True
    if random==0 :
        random= False
    else:
        print('random_state sets incorrectly!')
            
        
    # Setting the number of image patches to be extracted   
    num_patches = int(input(r"Please enter the number of pathces. Enter -1 to extract all available patches:"))
    
    #  Setting the visualization parameter:
    #  0: Do not plot image patches
    #  1: Ploting the image patches
    visualize = int(input("Would like to display image patches? (1 = yes,   0 = no): "))
    if visualize==1 :
        visualize= True
    if visualize==0 :
        visualize= False
    
    
    # Setting the intensity check parameter:
    # 1: exclude empty patches based on mean intensity of the image patch
    # 0: Do not exclude any patch
    intensity_check = int(input("Only include patches with high intestity? (1 = yes,   0 = no): "))
    if intensity_check==1 :
        random_state= True
    if intensity_check==0 :
        random_state= False
    
    print("\n")
    
    #Checking folder availability
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    WSIpatch_extractor.patch_extraction(wsi_obj,patchsize,output_directory,random,visualize,intensity_check,intensity_threshold,std_threshold,num_patches)
# Out:
# Please enter the patch size, for example 255: 255
# Please enter the output directory, for example C:/DATA/0_Washu-Aperio/out_dir/:C:/DATA/0_Washu-Aperio/out_dir/
# Please enter set the random variable (1 = randomize ,  0 = non-randomized)0
# Please enter the number of pathces. Enter -1 to extract all available patches:10
# Would like to display image patches? (1 = yes,   0 = no): 1
# Only include patches with high intestity? (1 = yes,   0 = no): 1
#
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  97931
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/normalized_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/H_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/E_tiles/ folder already exists.
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/229_1_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/230_1_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/231_1_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/312_1_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/65_2_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/86_3_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/251_3_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/256_3_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/257_3_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/256_4_original.tif
# Please enter the patch size, for example 255: 255
# Please enter the output directory, for example C:/DATA/0_Washu-Aperio/out_dir/:C:/DATA/0_Washu-Aperio/out_dir/
# Please enter set the random variable (1 = randomize ,  0 = non-randomized)0
# Please enter the number of pathces. Enter -1 to extract all available patches:10
# Would like to display image patches? (1 = yes,   0 = no): 1
# Only include patches with high intestity? (1 = yes,   0 = no): 0
#
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  97931
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/normalized_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/H_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/E_tiles/ folder already exists.
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/0_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/1_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/2_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/3_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/4_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/5_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/6_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/7_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/8_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/9_0_original.tif
# Please enter the patch size, for example 255:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-272be1e27e02> in <module>
#       3     std_threshold = 15
#       4     #Setting the patch size
# ----> 5     patchsize = int(input(r"Please enter the patch size, for example 255: "))
#       6
#       7     #Setting the output directory
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Extracting few (100) image patches

# %%
print("\n**********************< Extract few patches from WSI (non-overlapping) >************************\n")
patchsize = 256
output_directory = "C:/DATA/0_Washu-Aperio/out_dir/"
random= False
visualize = True
intensity_check = False
num_patches = 10 # set to -1 to extract all patches
intensity_threshold = 250
std_threshold = 15

WSIpatch_extractor.patch_extraction(wsi_obj,patchsize,output_directory,random,visualize,intensity_check,intensity_threshold,std_threshold,num_patches)
# Out:
# **********************< Extract few patches from WSI (non-overlapping) >************************
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  96790
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/normalized_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/H_tiles/ folder already exists.
# C:/DATA/0_Washu-Aperio/out_dir/Imagepatches/E_tiles/ folder already exists.
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/0_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/1_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/2_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/3_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/4_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/5_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/6_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/7_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/8_0_original.tif
# SavingC:/DATA/0_Washu-Aperio/out_dir/Imagepatches/original_tiles/9_0_original.tif
