# %% [markdown]
# # Reading Whole Slide Images and Extract Patches
#
# Click to open in:  \[[GitHub](https://github.com/DIDSR/wsi_processing_toolbox)\]
# #####  For questions regarding this code, please contact: Seyed.Kahaki

# %% [markdown]
# ## What is this Notebook?
#
# This Jupyter notebook is designed for accessibility and convenience, as it can be executed on any computer via a standard web browser without the need to install any programming language beforehand. Thanks to Google Colaboratory's capabilities, it can be run remotely over the Internet, completely free of charge. To initiate a session with Colab, click on either of the two blue checkboxes above, ensuring that "colab" is visible in the address bar. If a left click doesn't activate the function for you, right-click on "Open in Colab" and select "Open in new tab". Please take a moment to familiarize yourself with the drop-down menus located near the top of the window. These will enable you to edit the notebook during the session. For instance, you might choose to replace the image files used in this demo with your own, or to experiment with different function parameters. It's important to note that the original version of this notebook on GitHub or Colab cannot be permanently altered by a regular user, so you need not worry about inadvertently making irreversible changes.
#
# If you wish to save any modifications you make to this notebook, navigate to the notebook's File Menu.
#
# In case you'd like to operate this notebook on a platform other than Colab, you'll need to configure your Python environment as outlined in the README file.

# %% [markdown]
# ## WSI Reader Demo
# This demonstration guides you through the process of utilizing SlidePro to interact with a whole slide image (WSI). The objective is to provide you with an understanding of how to load a WSI, extract relevant information, and subsequently retrieve image patches.
#
# In the first part of this demo, we focus on loading a sample WSI. This involves utilizing SlidePro's built-in functions to successfully read the image file. These functions are designed to handle the complexities of WSI files, which can be vast and multi-layered, ensuring that the image is loaded accurately and efficiently.
#
# After successfully loading the WSI, we proceed to extract key information about the image. This involves identifying and logging characteristics such as the slide's dimensions, the number of image layers, and the magnification levels. By understanding these attributes, we can more effectively analyze the slide and extract relevant sections for further study.
#
# The next stage of this demonstration involves extracting image patches from the loaded WSI. We achieve this through using SlidePro's patch extraction functions. This is a critical step as it enables us to focus on specific areas of the slide, which can then be subjected to detailed analysis.
#
# To conclude, we delve into specific modules of the SlidePro software. We examine the wsireader module in greater detail, discussing its role in loading WSIs and the methods it provides for interacting with these images. We also examine the slide_info module, discussing how it enables the extraction of key information from a slide.
#
# Throughout this demonstration, we'll show you how to use the SlidePro's capabilities to perform a range of tasks on WSIs, from the basic reading of the image to the extraction and detailed analysis of specific sections. This demo should provide you with a solid foundation for working with whole slide images using the SlidePro.

# %% [markdown]
# ## Environment Configuration
# ### Installation of SliePro and related dependencies
#
# If you're not utilizing Google Colab as your platform, or if this isn't your first time running the notebook during the current runtime session on Colab, you can bypass the next cell. If you choose to run it regardless, you might encounter an error message; however, this won't negatively impact your session. On Google Colab, this cell is responsible for installing SlidePro and other required software. Should you encounter any error messages, they are likely harmless and can be disregarded.
#
# If you're running this notebook outside of Colab, it is assumed that SlidePro is already installed in your environment. If this is not the case, please refer to the installation instructions provided in our README file.

# %%
#!apt-get -y install libopenjp2-7-dev libopenjp2-tools openslide-tools | tail --line 1
#!pip install SlidePro | tail --line 1

print("Installation is done.")
# Out:
# Installation is done.

# %% [markdown]
# ### Cleaning up residual files from prior sessions
# The following cell is designed to delete the 'tmp' directory, assuming it exists due to an earlier run of this notebook. If this is your initial run, you can disregard this step.

# %%
#![ -d 'dataset/images' ] && ( echo "deleting tmp directory"; rm -rf 'dataset/images' )

# %% [markdown]
# ## Read Whole Slide Image
# ### Loading Necessary Libraries
# This step involves importing various Python modules that are needed for our analysis.

# %%
import os

from readwsi.readwsi import ReadWsi
import matplotlib.pyplot as plt

# %% [markdown]
# ## get file path and file name  and reading with wsi_reader

# %%
while True:

    dir_file = input(r"enter the file directory ...?    forexample: C:\Users\data ---->")
    file_name = input("What is the file name...?    forexample: a.svs ---->")
    print("\n")
    path = dir_file + "\\" + file_name

    if os.path.exists(path):
        wsi_obj =ReadWsi.wsi_reader(path)
        break
    else:
        print(" !!! path file error....... please enter carefully" )

print(" Done...")
# Out:
# enter the file directory ...?    forexample: C:\Users\data ---->C:\DATA\0_Washu-Aperio
# What is the file name...?    forexample: a.svs ---->aperio-002-0_.svs
#
#
#  Done...

# %% [markdown]
# ### 4.Check the WSI object  :

# %%
print(wsi_obj)
print(wsi_obj.level_dimensions)
# Out:
# OpenSlide('C:\\DATA\\0_Washu-Aperio\\aperio-002-0_.svs')
# ((123503, 38380), (30875, 9595), (7718, 2398), (3859, 1199))

# %% [markdown]
# ## use of patch extraction function

# %%
patchsize= 256
output_directory = dir_file + '\\input_output\\'

print("outpot directory is : ",output_directory)

# patch_extraction (openslide_object , patch size , path for saving patches , perform_segmentation_state , random_state)
#tile = ReadWsi.patch_extraction(wsi_obj,patchsize,output_directory,True,True)
#plt.imshow(tile)

print("\n**********************< without randam state >************************\n")

random_state = False
patch_numbers = 4
ReadWsi.patch_extraction(wsi_obj,patchsize,output_directory,random_state,patch_numbers)

print("\n**********************< with randam state >************************\n")
random_state = True
patch_numbers = 4
ReadWsi.patch_extraction(wsi_obj,patchsize,output_directory,random_state,patch_numbers)
# Out:
# outpot directory is :  C:\DATA\0_Washu-Aperio\input_output\
#
# **********************< without randam state >************************
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  96790
# created folder :  C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/
# created folder :  C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/original_tiles/
# created folder :  C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/normalized_tiles/
# created folder :  C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/H_tiles/
# created folder :  C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/E_tiles/
# **********************< with randam state >************************
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  96790
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/original_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/normalized_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/H_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/E_tiles/ folder already exists.

# %% [markdown]
# ## use of patch extraction with normalization function

# %%
print("\n**********************< without randam state >************************\n")

random_state = False
patch_numbers = 2

ReadWsi.patch_extraction_with_normalized_tiles(wsi_obj,patchsize,output_directory,random_state,patch_numbers)


print("\n**********************< with randam state >************************\n")

random_state = True
patch_numbers = 2

ReadWsi.patch_extraction_with_normalized_tiles(wsi_obj,patchsize,output_directory,random_state,patch_numbers)
# Out:
# **********************< without randam state >************************
#
# The number of levels in the tiles object are:  18
# The dimensions of data in each level are:  ((1, 1), (2, 1), (4, 2), (8, 3), (16, 5), (31, 10), (61, 19), (121, 38), (242, 75), (483, 150), (965, 300), (1930, 600), (3860, 1200), (7719, 2399), (15438, 4798), (30876, 9595), (61752, 19190), (123503, 38380))
# Total number of tiles = :  96790
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/original_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/normalized_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/H_tiles/ folder already exists.
# C:\DATA\0_Washu-Aperio\input_output\images/saved_tiles/E_tiles/ folder already exists.
# C:\Users\SeyedM.MousaviKahaki\Anaconda3\lib\site-packages\numpy\lib\function_base.py:495: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\SeyedM.MousaviKahaki\Anaconda3\lib\site-packages\numpy\core\_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# C:\Users\SeyedM.MousaviKahaki\Documents\slidepro\wsi_processing_dev\readwsi\normalization.py:134: RuntimeWarning: Degrees of freedom <= 0 for slice
#   eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))
# C:\Users\SeyedM.MousaviKahaki\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\SeyedM.MousaviKahaki\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2680: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-7-93c0e93a043c> in <module>
#       4 patch_numbers = 2
#       5
# ----> 6 ReadWsi.patch_extraction_with_normalized_tiles(wsi_obj,patchsize,output_directory,random_state,patch_numbers)
#       7
#       8
#
# ~\Documents\slidepro\wsi_processing_dev\readwsi\readwsi.py in patch_extraction_with_normalized_tiles(wsi_obj, patch_size, output_folder, random_state, patch_number)
#     311                     if temp_tile_np.mean() < 230 and temp_tile_np.std() > 15:
#     312                        # print("Processing tile number:", tile_name)
# --> 313                         norm_img, H_img, E_img = normalization.norm_HnE(temp_tile_np, Io=240, alpha=1, beta=0.15)
#     314                         # Save original tile
#     315                         tiff.imsave(orig_tile_dir_name + tile_name + "_original.tif", temp_tile_np)
#
# ~\Documents\slidepro\wsi_processing_dev\readwsi\normalization.py in norm_HnE(img, Io, alpha, beta)
#     132     #Estimate covariance matrix of ODhat (transposed)
#     133     # and then compute eigen values & eigenvectors.
# --> 134     eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))
#     135
#     136
#
# ~\Anaconda3\lib\site-packages\numpy\core\overrides.py in eigh(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in eigh(a, UPLO)
#    1456
#    1457     signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1458     w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1459     w = w.astype(_realType(result_t), copy=False)
#    1460     vt = vt.astype(result_t, copy=False)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#      92
#      93 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# ---> 94     raise LinAlgError("Eigenvalues did not converge")
#      95
#      96 def _raise_linalgerror_svd_nonconvergence(err, flag):
#
# LinAlgError: Eigenvalues did not converge

# %% [markdown]
# ### End of File
